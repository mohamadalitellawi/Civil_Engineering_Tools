# %%
from mat_ceng.csi_toolkit import ETABSAPI, setup_logging

setup_logging(log_level="INFO")
# Out:
# 2025-10-14 06:27:57 | INFO     | mat_ceng.csi_toolkit.utils.logging_config:setup_logging:64 | Logging initialized - Level: INFO

# %%
with ETABSAPI() as etabs:
    etabs.connect(visible=True)
    etabs.create_template_model(num_stories=5, story_height=3.5)
    etabs.save_model("building.edb")
# Out:
# 2025-10-14 06:28:45 | INFO     | mat_ceng.csi_toolkit.core.connection:__init__:61 | Initializing ConnectionManager for ETABS
# 2025-10-14 06:28:45 | INFO     | mat_ceng.csi_toolkit.core.base_api:__init__:40 | Initialized ETABS API
# 2025-10-14 06:28:45 | INFO     | mat_ceng.csi_toolkit.etabs.api:__init__:38 | ETABS API initialized
# 2025-10-14 06:28:45 | INFO     | mat_ceng.csi_toolkit.core.connection:create_new_instance:156 | Creating new ETABS instance...
# 2025-10-14 06:28:45 | INFO     | mat_ceng.csi_toolkit.core.connection:_load_api_dll:88 | Loaded API DLL: C:\Program Files\Computers and Structures\ETABS 22\ETABSv1.dll
# 2025-10-14 06:28:45 | ERROR    | mat_ceng.csi_toolkit.core.base_api:connect:68 | Connection failed: Failed to create ETABS instance: 'Helper' object has no attribute 'CreateObjectProgID'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\py\Civil_Engineering_Tools\src\mat_ceng\csi_toolkit\core\connection.py:163, in ConnectionManager.create_new_instance(self, visible, model_path)
#     162     helper = ETABSv1.Helper()
# --> 163     self.sap_object = helper.CreateObjectProgID("CSI.ETABS.API.ETABSObject")
#     164 elif self.software == CSISoftware.SAP2000:
#
# AttributeError: 'Helper' object has no attribute 'CreateObjectProgID'
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[4], line 2
#       1 with ETABSAPI() as etabs:
# ----> 2     etabs.connect(visible=True)
#       3     etabs.create_template_model(num_stories=5, story_height=3.5)
#       4     etabs.save_model("building.edb")
#
# File ~\py\Civil_Engineering_Tools\src\mat_ceng\csi_toolkit\core\base_api.py:60, in BaseCSIAPI.connect(self, attach_to_existing, visible, model_path)
#      58     self.sap_object, self.model = self.connection_manager.attach_to_instance()
#      59 else:
# ---> 60     self.sap_object, self.model = self.connection_manager.create_new_instance(
#      61         visible=visible,
#      62         model_path=model_path
#      63     )
#      65 self.is_connected = True
#      66 logger.info(f"Connected to {self.software.value}")
#
# File ~\py\Civil_Engineering_Tools\src\mat_ceng\csi_toolkit\core\connection.py:197, in ConnectionManager.create_new_instance(self, visible, model_path)
#     194     return self.sap_object, self.sap_model
#     196 except Exception as e:
# --> 197     raise ConnectionError(
#     198         f"Failed to create {self.software.value} instance: {str(e)}"
#     199     )
#
# ConnectionError: Failed to create ETABS instance: 'Helper' object has no attribute 'CreateObjectProgID'
