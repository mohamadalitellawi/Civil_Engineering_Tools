# %%
# %matplotlib inline

# %%
from matplotlib.figure import Figure
fig = Figure()
ax = fig.gca()
ax.plot([1, 2, 3], [4, 5, 6])
fig

# %%
from sectionproperties.pre.library.steel_sections import angle_section

# %%
geom = angle_section(100, 100, t=10.3, r_r=5, r_t=5, n_r=12)

# %%
ax = geom.plot_geometry()

# %%
fig = ax.get_figure()

# %%
ax.set_title("My Title")
fig

# %%
fig.savefig(r"output.png")
